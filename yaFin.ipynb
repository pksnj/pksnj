# %% [markdown]
# <a href="https://colab.research.google.com/github/pksnj/pksnj/blob/main/yaFin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download data from yahoo Finance

# %% [markdown]
# Install and Import Dependencies
#
# https://pypi.org/project/yfinance/

# %%
# !pip install -q yfinance

# %%
import yfinance as yf

# %%
msft = yf.Ticker("MSFT")
# get stock info
msft.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 221000,
# ...

# %%
# get historical market data
hist = msft.history(period="max")

# %%
# show actions (dividends, splits)
msft.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-09-21 00:00:00-04:00       0.00           2.0
# 1990-04-16 00:00:00-04:00       0.00           2.0
# 1991-06-27 00:00:00-04:00       0.00           1.5
# 1992-06-15 00:00:00-04:00       0.00           1.5
# 1994-05-23 00:00:00-04:00       0.00           2.0
# ...                              ...           ...
# 2021-08-18 00:00:00-04:00       0.56           0.0
# 2021-11-17 00:00:00-05:00       0.62           0.0
# 2022-02-16 00:00:00-05:00       0.62           0.0
# 2022-05-18 00:00:00-04:00       0.62           0.0
# 2022-08-17 00:00:00-04:00       0.62           0.0
#
# [84 rows x 2 columns]

# %%
# show dividends
msft.dividends
# Out:
# Date
# 2003-02-19 00:00:00-05:00    0.08
# 2003-10-15 00:00:00-04:00    0.16
# 2004-08-23 00:00:00-04:00    0.08
# 2004-11-15 00:00:00-05:00    3.08
# 2005-02-15 00:00:00-05:00    0.08
#                              ...
# 2021-08-18 00:00:00-04:00    0.56
# 2021-11-17 00:00:00-05:00    0.62
# 2022-02-16 00:00:00-05:00    0.62
# 2022-05-18 00:00:00-04:00    0.62
# 2022-08-17 00:00:00-04:00    0.62
# Name: Dividends, Length: 75, dtype: float64

# %%
# show splits
msft.splits
# Out:
# Date
# 1987-09-21 00:00:00-04:00    2.0
# 1990-04-16 00:00:00-04:00    2.0
# 1991-06-27 00:00:00-04:00    1.5
# 1992-06-15 00:00:00-04:00    1.5
# 1994-05-23 00:00:00-04:00    2.0
# 1996-12-09 00:00:00-05:00    2.0
# 1998-02-23 00:00:00-05:00    2.0
# 1999-03-29 00:00:00-05:00    2.0
# 2003-02-18 00:00:00-05:00    2.0
# Name: Stock Splits, dtype: float64

# %%
# show financials
msft.financials
msft.quarterly_financials
# Out:
#                                            2022-09-30     2022-06-30  \
# Research Development                     6628000000.0   6849000000.0
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       21572000000.0  20487000000.0
# Minority Interest                                None           None
# Net Income                              17556000000.0  16740000000.0
# Selling General Administrative           6524000000.0   8053000000.0
# Gross Profit                            34670000000.0  35436000000.0
# Ebit                                    21518000000.0  20534000000.0
# Operating Income                        21518000000.0  20534000000.0
# Other Operating Expenses                         None           None
# Interest Expense                         -500000000.0   -492000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# ...

# %%
# show major holders
msft.major_holders
# Out:
#         0                                      1
# 0   0.07%        % of Shares Held by All Insider
# 1  71.93%       % of Shares Held by Institutions
# 2  71.99%        % of Float Held by Institutions
# 3    5943  Number of Institutions Holding Shares

# %%
# show institutional holders
msft.institutional_holders
# Out:
#                             Holder     Shares Date Reported   % Out  \
# 0       Vanguard Group, Inc. (The)  628109007    2022-06-29  0.0843
# 1                   Blackrock Inc.  522551885    2022-06-29  0.0701
# 2         State Street Corporation  293557993    2022-06-29  0.0394
# 3                         FMR, LLC  204088395    2022-09-29  0.0274
# 4    Price (T.Rowe) Associates Inc  195859819    2022-06-29  0.0263
# 5    Geode Capital Management, LLC  136945361    2022-06-29  0.0184
# 6                   Morgan Stanley  101931745    2022-06-29  0.0137
# 7          Capital World Investors   98825477    2022-06-29  0.0133
# 8        JP Morgan Chase & Company   91034485    2022-06-29  0.0122
# 9  Capital International Investors   85116879    2022-06-29  0.0114
#
#           Value
# 0  155212017103
# 1  129127796621
# 2   72541115829
# 3   50432283413
# 4   48398919992
# 5   33840568240
# 6   25188353569
# 7   24420763681
# 8   22495531643
# 9   21033232021

# %%
# show balance sheet
msft.balance_sheet
msft.quarterly_balance_sheet
# Out:
#                                                 2022-09-30    2022-06-30  \
# Intangible Assets                             1.080800e+10  1.129800e+10
# Total Liab                                    1.862180e+11  1.982980e+11
# Total Stockholder Equity                      1.735660e+11  1.665420e+11
# Other Current Liab                            5.684800e+10  5.938400e+10
# Total Assets                                  3.597840e+11  3.648400e+11
# Common Stock                                  8.853500e+10  8.693900e+10
# Other Current Assets                          1.802100e+10  1.693200e+10
# Retained Earnings                             9.237400e+10  8.428100e+10
# Other Liab                                    2.822000e+10  3.085300e+10
# Good Will                                     6.745900e+10  6.752400e+10
# Gains Losses Not Affecting Retained Earnings -7.343000e+09 -4.678000e+09
# Other Assets                                  2.348200e+10  2.189700e+10
# ...

# %%
# show cashflow
msft.cashflow
msft.quarterly_cashflow
# Out:
#                                              2022-09-30    2022-06-30  \
# Investments                                4.360000e+09 -4.570000e+08
# Change To Liabilities                     -4.889000e+09  1.520500e+10
# Total Cashflows From Investing Activities -3.132000e+09 -9.729000e+09
# Net Borrowings                            -1.000000e+09 -1.000000e+09
# Total Cash From Financing Activities      -1.088300e+10 -1.326900e+10
# Change To Operating Activities            -4.834000e+09  3.540000e+08
# Issuance Of Stock                          5.750000e+08  4.610000e+08
# Net Income                                 1.755600e+10  1.674000e+10
# Change In Cash                             8.953000e+09  1.433000e+09
# Repurchase Of Stock                       -5.573000e+09 -8.757000e+09
# Effect Of Exchange Rate                   -2.300000e+08 -1.980000e+08
# Total Cash From Operating Activities       2.319800e+10  2.462900e+10
# ...

# %%
# show earnings
msft.earnings
msft.quarterly_earnings
# Out:
#              Revenue     Earnings
# Quarter
# 4Q2021   51728000000  18765000000
# 1Q2022   49360000000  16728000000
# 2Q2022   51865000000  16740000000
# 3Q2022   50122000000  17556000000

# %%
# show sustainability
msft.sustainability
# Out:
#                                      Value
# 2022-8
# palmOil                              False
# controversialWeapons                 False
# gambling                             False
# socialScore                           8.39
# nuclear                              False
# furLeather                           False
# alcoholic                            False
# gmo                                  False
# catholic                             False
# socialPercentile                      None
# peerCount                              105
# governanceScore                       5.33
# environmentPercentile                 None
# animalTesting                        False
# tobacco                              False
# totalEsg                             15.24
# highestControversy                       3
# esgPerformance                  UNDER_PERF
# coal                                 False
# pesticides                           False
# adult                                False
# ...

# %%
# show analysts recommendations
msft.recommendations
# Out:
#                                    Firm       To Grade From Grade Action
# Date
# 2012-03-16 08:19:00      Argus Research            Buy                up
# 2012-03-19 14:00:00      Hilliard Lyons  Long-Term Buy              main
# 2012-03-22 07:03:00      Morgan Stanley     Overweight              main
# 2012-04-03 11:53:00                 UBS            Buy              main
# 2012-04-20 06:18:00       Deutsche Bank            Buy              main
# ...                                 ...            ...        ...    ...
# 2022-10-26 12:58:51      Wolfe Research     Outperform              main
# 2022-10-26 13:25:50  Evercore ISI Group     Outperform              main
# 2022-10-26 13:28:29         BMO Capital     Outperform              main
# 2022-10-27 11:14:36          Rosenblatt            Buy              main
# 2022-11-02 10:29:21           Macquarie        Neutral              init
#
# [424 rows x 4 columns]

# %%
# show next event (earnings, etc)
msft.calendar
# Out:
#                                     0                    1
# Earnings Date     2023-01-23 10:59:00  2023-01-27 12:00:00
# Earnings Average                 2.29                 2.29
# Earnings Low                     2.23                 2.23
# Earnings High                    2.36                 2.36
# Revenue Average           52969300000          52969300000
# Revenue Low               52389000000          52389000000
# Revenue High              53475000000          53475000000

# %%
# show all earnings dates
msft.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2023-10-23 06:00:00-04:00           NaN           NaN          NaN
# 2023-07-24 06:00:00-04:00           NaN           NaN          NaN
# 2023-04-24 06:00:00-04:00           NaN           NaN          NaN
# 2023-01-23 05:00:00-05:00          2.29           NaN          NaN
# 2022-10-25 12:00:00-04:00          2.30          2.35       0.0204
# ...                                 ...           ...          ...
# 1994-01-19 00:00:00-05:00          0.03          0.03       0.0189
# 1993-10-20 00:00:00-04:00          0.02          0.02       0.0181
# 1993-07-28 00:00:00-04:00          0.03          0.03       0.0172
# 1993-04-14 00:00:00-04:00          0.02          0.03       0.0196
# 1993-01-16 00:00:00-05:00          0.02          0.02      -0.0041
#
# [124 rows x 3 columns]

# %%
# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin
# Out:
# '-'

# %%
# show options expirations
msft.options
# Out:
# ('2022-11-18',
#  '2022-11-25',
#  '2022-12-02',
#  '2022-12-09',
#  '2022-12-16',
#  '2022-12-23',
#  '2023-01-20',
#  '2023-02-17',
#  '2023-03-17',
#  '2023-04-21',
#  '2023-06-16',
#  '2023-09-15',
#  '2024-01-19',
#  '2024-06-21',
#  '2025-01-17')

# %%
# show news
msft.news
# Out:
# [{'uuid': 'b94bd6b8-8b11-3d8b-b07c-db5fbbb61941',
#   'title': 'Largest U.S. Pension Buys Up Apple, Intel, and 2 More Big Stocks',
#   'publisher': 'Barrons.com',
#   'link': 'https://finance.yahoo.com/m/b94bd6b8-8b11-3d8b-b07c-db5fbbb61941/largest-u.s.-pension-buys-up.html',
#   'providerPublishTime': 1668344400,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/vu0axBOg_DHTVnGjC0K89g--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/5bf282275fb6a821e623af625688cbb7',
#      'width': 1280,
#      'height': 640,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/.NNdc7OaBb0KZP38TDErJw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/5bf282275fb6a821e623af625688cbb7',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['INTC', 'AAPL', 'MSFT', '^GSPC']},
# ...

# %%
# get option chain for specific expiration
opt = msft.option_chain('2022-11-18')
# data available via: opt.calls, opt.puts
opt.puts
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   MSFT221118P00125000 2022-11-11 14:30:28+00:00   125.0       0.01    0.00
# 1   MSFT221118P00130000 2022-11-03 13:40:43+00:00   130.0       0.01    0.00
# 2   MSFT221118P00135000 2022-11-07 14:50:20+00:00   135.0       0.01    0.00
# 3   MSFT221118P00140000 2022-11-10 17:26:29+00:00   140.0       0.01    0.00
# 4   MSFT221118P00145000 2022-11-10 14:30:07+00:00   145.0       0.04    0.00
# ..                  ...                       ...     ...        ...     ...
# 72  MSFT221118P00410000 2022-10-20 13:46:51+00:00   410.0     171.60  162.20
# 73  MSFT221118P00415000 2022-10-14 19:49:50+00:00   415.0     185.30  167.15
# 74  MSFT221118P00420000 2022-09-07 14:12:15+00:00   420.0     166.15  182.35
# 75  MSFT221118P00430000 2022-09-26 15:26:03+00:00   430.0     191.12  193.00
# 76  MSFT221118P00460000 2022-04-21 17:05:26+00:00   460.0     173.93  205.60
#
# ...

# %%
#Multiple tickers
data = yf.download("SPY AAPL", start="2022-01-01", end="2022-04-30")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
display(data)
# Out:
#              Adj Close                   Close                    High  \
#                   AAPL         SPY        AAPL         SPY        AAPL
# Date
# 2022-01-03  180.959747  472.242310  182.009995  477.709991  182.880005
# 2022-01-04  178.663086  472.084137  179.699997  477.549988  182.940002
# 2022-01-05  173.910660  463.019135  174.919998  468.380005  180.169998
# 2022-01-06  171.007507  462.584137  172.000000  467.940002  175.300003
# 2022-01-07  171.176529  460.755310  172.169998  466.089996  174.139999
# ...                ...         ...         ...         ...         ...
# 2022-04-25  162.146454  424.921417  162.880005  428.510010  163.169998
# 2022-04-26  156.093842  412.615356  156.800003  416.100006  162.339996
# 2022-04-27  155.864883  413.775543  156.570007  417.269989  159.789993
# 2022-04-28  162.903030  424.227295  163.639999  427.809998  164.520004
# 2022-04-29  156.940002  408.549683  157.649994  412.000000  166.199997
#
# ...

# %%
data.Close.plot()
